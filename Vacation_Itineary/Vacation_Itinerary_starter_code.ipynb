# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Using cached gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (7.31.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (5.1.1)
# Collecting geojson>=2.0.0
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: pexpect>4.3 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: appnope in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: backcall in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: pygments in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: decorator in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: nest-asyncio in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: fastjsonschema in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: importlib-metadata in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.3)
# Requirement already satisfied: typing-extensions in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: argon2-cffi in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: jinja2 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: nbconvert in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: prometheus-client in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: bleach in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: testpath in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: packaging in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: webencodings in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/caed/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076111 sha256=bd095a384a3122498556c774509e7ddc3d7320a626b3841b86c0292b09edde27
#   Stored in directory: /Users/caed/Library/Caches/pip/wheels/3d/1c/cb/c46f4199210e632b28d78d05a00bfdccbf6dfcd3f5b051d6bf
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import gmaps.datasets

# Import API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.

vacation_df = pd.read_csv("/Users/caed/Desktop/Data_Repo/World_Weather_analysis/Vacation_Search/WeatherPy_vacation.csv")
vacation_df
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 0          0  Arraial Do Cabo      BR     70.38           clear sky -22.9661
# 1          1           Atuona      PF     77.40          few clouds  -9.8000
# 2          2     Punta Arenas      CL     32.11           clear sky -53.1500
# 3          5           Avarua      CK     75.25          few clouds -21.2078
# 4          6   Cabo San Lucas      MX     84.51       broken clouds  22.8909
# ..       ...              ...     ...       ...                 ...      ...
# 566      638       Orimattila      FI     68.38     overcast clouds  60.8047
# 567      639           Abaete      BR     58.73           clear sky -19.1600
# 568      640        Singaraja      ID     81.39    scattered clouds  -8.1120
# 569      641      Nyuksenitsa      RU     74.91       broken clouds  60.4128
# 570      642          Grafton      US     76.41           clear sky  42.2070
#
#           Lng                Hotel Name
# 0    -42.0278       Pousada Porto Praia
# 1   -139.0333               Villa Enata
# 2    -70.9167                Hotel Hain
# 3   -159.7750              Paradise Inn
# 4   -109.9124    Hotel Tesoro Los Cabos
# ..        ...                       ...
# 566   25.7300                hotel Tent
# 567  -45.4458           Hotel Millenium
# 568  115.0882  Puri Bagus Lovina Resort
# 569   44.2397             Sukhona Hotel
# 570  -71.6856           The Grafton Inn
#
# [571 rows x 8 columns]

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.


vacation_start = vacation_df.loc[vacation_df["City"] == "Portland" ]
vacation_end = vacation_df.loc[vacation_df["City"] == "Portland" ]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Victoria" ]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Bow Island" ]
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Pemberton" ]

# %%
### 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
#start = 
start = vacation_start['Lat'].to_numpy()[0], vacation_start['Lng'].to_numpy()[0]

end = vacation_end['Lat'].to_numpy()[0], vacation_end['Lng'].to_numpy()[0]

stop1 = vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0]

stop2 = vacation_stop2['Lat'].to_numpy()[0], vacation_stop2['Lng'].to_numpy()[0]

stop3 = vacation_stop3['Lat'].to_numpy()[0], vacation_stop3['Lng'].to_numpy()[0]

print(start, end, stop1, stop2, stop3)
# Out:
# (45.5234, -122.6762) (45.5234, -122.6762) (48.4329, -123.3693) (49.8668, -111.3684) (50.3164, -122.8027)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
#fig = gmaps.figure()
#trip = gmaps.directions_layer(start, end)
#fig.add_layer(trip)
#fig
fig = gmaps.figure()
fulltrip = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(fulltrip)
fig
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0       33    Portland      US     66.47           clear sky  45.5234
# 1       33    Portland      US     66.47           clear sky  45.5234
# 2      301    Victoria      CA     60.62       broken clouds  48.4329
# 3      433  Bow Island      CA     62.47       broken clouds  49.8668
# 4      293   Pemberton      CA     66.22       broken clouds  50.3164
#
#         Lng                                  Hotel Name
# 0 -122.6762  Embassy Suites by Hilton Portland Downtown
# 1 -122.6762  Embassy Suites by Hilton Portland Downtown
# 2 -123.3693             Chateau Victoria Hotel & Suites
# 3 -111.3684                           Silver Sage Motel
# 4 -122.8027                      Pemberton Valley Lodge

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
